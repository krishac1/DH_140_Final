# %% [markdown]
# # DH Final Project - Krisha Chokshi
# ## Examining Opportunity through the Lens of Gender
# ## 08.01.24

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Motivation
# I chose to conduct this Final Project on the impact of gender. I am a woman in STEM who has always been outnumbered in the technical classes that I have taken. I think it is essential for all people - regardless of their gender, race, nor any other distinguishing factors to be treated as equal. One of the largest comments I have always faced is that my gender does has not made a difference - and the struggles I have seen in my journey so far and what I have been able to overcome are not real. I wanted to dedicate this project to all underrepresented people who have felt their journeys have been undermined.
#
# ### Question
# Hence, the focus on my project is exploring the question:
# **Does gender still play a role in achieving and navigating educational, and professional opportunities?**
#
# ### Overview
# I wanted to explore multiple sides to this question which means focusing on the educational disparities in gender, professional disparities, and also tackling the question of time with the usage of the word *still* in my research question. Additionally, I wanted to understand whether this is specific to any country / region. Some of the sub-questions I wish to explore with my analysis include:
#
# 1. What does professional representation look like by gender in popular jobs?
# 2. How are men/women involved with out of work activities like care without pay?
# 3. What does comfort in the workplace look like by gender?
# 4. Is there any pay discrepancy between the genders?
# 5. Does gender make more or less of a difference in different countries?
# 6. What is the difference in education recieved by men and women?
#
# I aim to not only support and answer these sub-questions and my main question with data visualizations, but also external research and sources to ensure I am recieving a well rounded grasp of the *context* of the data I explore.
#
# ### Sources and Data
# * Link to sources
# * Narrative description

# %% [markdown]
# ## Information about Data

# %% [markdown]
# * Explores and presents information about data
# * Summary information about data, summary stats, identification of missing / incorrect / outlier data, and data processing
# * 4 exploratory data visualizations

# %% [markdown]
# ## Methods of Research

# %% [markdown]
# I will start by comparing professional representation by gender and examining the M:F ratio in some popular jobs. I scoured the internet for potential data sources that may display this.
#
# Here is a site I found that accomplishes this: https://data.gov.ie/dataset/gender-breakdown-by-grade-within-grade-stream/resource/f78cefe7-7170-4184-b21d-4bee89e2c13f

# %% [markdown]
# This bar plot fully displays the male to female ratio for each of these roles so that we can understand which jobs are more popular.
# Here is the code:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the CSV file into a DataFrame
df = pd.read_csv("gender_by_profession.csv")

# Convert the percentage columns to numeric (removing % sign)
df['Percentage of Females in Grade'] = df['Percentage of Females in Grade'].str.rstrip('%').astype(float)
df['Percentage of Males in Grade'] = df['Percentage of Males in Grade'].str.rstrip('%').astype(float)

# Plotting
fig, ax = plt.subplots(figsize=(14, 12))

# Y-axis labels (combining Grade Stream and Grade for uniqueness)
y_labels = df['Grade ']

# Indices for positions on the y-axis
y = np.arange(len(df))

# Plotting Female percentages
ax.barh(y, df['Percentage of Females in Grade'], height=0.4, label='Females', color='skyblue')

# Plotting Male percentages, offset by the height of the bars for overlapping
ax.barh(y, df['Percentage of Males in Grade'], height=0.4, left=df['Percentage of Females in Grade'], label='Males', color='salmon')

# Set y-ticks and labels
ax.set_yticks(y)
ax.set_yticklabels(y_labels, rotation=0)

# Set labels and title
ax.set_xlabel('Percentage')
ax.set_title('Gender Ratio per Role')

# Add legend
ax.legend()

# Display plot
plt.tight_layout()
plt.show()

# %% [markdown]
# However, we want to be able to see a better overall view of which jobs exactly are more popular for each gender so I decided to look through the data to figure this out and list the Male/Female dominated ones.

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv("gender_by_profession.csv")

# Convert the percentage columns to numeric (removing % sign)
df['Females'] = df['Percentage of Females in Grade'].str.rstrip('%').astype(float)
df['Males'] = df['Percentage of Males in Grade'].str.rstrip('%').astype(float)

# Identify male-dominated and female-dominated jobs
male_dominated_jobs = df[df['Males'] > df['Females']]
female_dominated_jobs = df[df['Females'] > df['Males']]

# Print the results
print("Male Dominated Jobs:")
print(male_dominated_jobs[['Grade ', 'Males', 'Females']])
print("\nFemale Dominated Jobs:")
print(female_dominated_jobs[['Grade ', 'Females', 'Males']])
# Out:
# Male Dominated Jobs:
#                             Grade    Males  Females
# 0                SECRETARY GENERAL  100.00     0.00
# 1              ASSISTANT SECRETARY   66.67    33.33
# 2                        PRINCIPAL   88.89    11.11
# 3              ASSISTANT PRINCIPAL   68.00    32.00
# 16              SERVICES ATTENDANT   54.55    45.45
# 17                SERVICES OFFICER   89.19    10.81
# 19  DIRECTOR METEORLOGICAL SERVICE  100.00     0.00
# 20                   LEGAL ADVISOR  100.00     0.00
# 21             INSPECTOR OF AUDITS  100.00     0.00
# 22      ASST DIRECTOR MET SERVICES  100.00     0.00
# 23  PRINCIPAL ADVISOR HIGHER LEVEL  100.00     0.00
# 24               PRINCIPAL AUDITOR  100.00     0.00
# 25                  SENIOR ADVISER  100.00     0.00
# 26   SENIOR ASSISTANT FIRE ADVISOR  100.00     0.00
# 27            SENIOR METEOROLOGIST  100.00     0.00
# 28     ARCHITECTURAL/ENG INSPECTOR   94.74     5.26
# 29          ASSISTANT FIRE ADVISOR  100.00     0.00
# 30             AUDITOR ENVIRONMENT   80.00    20.00
# 31          ENGINEER GRADE 1 CIVIL   75.00    25.00
# 32               INSPECTOR GRADE 2  100.00     0.00
# 33            INSPECTOR MECHANICAL  100.00     0.00
# 34                   METEOROLOGIST   74.19    25.81
# 35    PRINCIPAL METEOROLOGICAL OFF  100.00     0.00
# 36       QUANTITY SURVEYOR GRADE 1  100.00     0.00
# 37            SENIOR ARCHAEOLOGIST  100.00     0.00
# 38   SUPERVISING HOUSING INSPECTOR   85.71    14.29
# 42   ASSISTANT AUDITOR ENVIRONMENT   66.67    33.33
# 43          ENGINEER GRADE 3 CIVIL  100.00     0.00
# 44               HOUSING INSPECTOR   66.67    33.33
# 45       SENIOR BUILDING INSPECTOR  100.00     0.00
# 46           SENIOR VEHICLE TESTER  100.00     0.00
# 47       SUPERVISORY DRIVER TESTER  100.00     0.00
# 48                         AUDITOR  100.00     0.00
# 49             CHIEF DRIVER TESTER  100.00     0.00
# 51   SENIOR METEOROLOGICAL OFFICER   95.74     4.26
# 52        TECHNICAL GRADES LEVEL 4  100.00     0.00
# 53              BUILDING INSPECTOR  100.00     0.00
# 54                   DRIVER TESTER   93.46     6.54
# 55        DRIVER TESTER - CONTRACT  100.00     0.00
# 56          METEOROLOGICAL OFFICER   85.71    14.29
# 57                  VEHICLE TESTER  100.00     0.00
#
# Female Dominated Jobs:
#                            Grade   Females  Males
# 5        HIGHER EXECUTIVE OFFICER    53.51  46.49
# 6              PERSONAL ASSISTANT   100.00   0.00
# 7               EXECUTIVE OFFICER    57.64  42.36
# 8              PERSONAL SECRETARY   100.00   0.00
# 9           SECRETARIAL ASSISTANT    66.67  33.33
# 10                  STAFF OFFICER    75.76  24.24
# 11               CLERICAL OFFICER    85.71  14.29
# 12         CLERICAL OFF TEMPORARY   100.00   0.00
# 13  VISUALLY IMPAIRED TELEPHONIST    66.67  33.33
# 14                        CLEANER   100.00   0.00
# 15            CLEANER - PART TIME   100.00   0.00
# 18     SUPERINTENDENT OF CLEANERS   100.00   0.00
# 39         ADMINISTRATIVE OFFICER   100.00   0.00
# 40                  ARCHAEOLOGIST   100.00   0.00
# 41                      ARCHITECT   100.00   0.00
# 50                      LIBRARIAN   100.00   0.00

# %% [markdown]
# Now let's analyze how much care work men/women do on average to understand where they may be spending their time other than work. This is to see how much women/men work in terms of unpaid labor. I found this dataset to work through this: https://www.kaggle.com/datasets/imtkaggleteam/womens-right

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'unpaid_work.csv' 
data = pd.read_csv(file_path)

sorted_data = data.sort_values(by='Female to male ratio of time devoted to unpaid care work (OECD (2014))', ascending=False)

# Select top 15 countries
top_countries = sorted_data.head(15)
top_ratios = top_countries['Female to male ratio of time devoted to unpaid care work (OECD (2014))']
top_entities = top_countries['Entity']

plt.figure(figsize=(12, 8))
plt.pie(top_ratios, labels=top_entities, autopct='%1.1f%%', startangle=140)

# Add title and display the plot
plt.title('Top 10 Countries by Female to Male Ratio of Unpaid Care Work (2014)\n\n')
plt.axis('equal')
plt.show()

# %% [markdown]
# This pie chart represents the Top 15 countries that have the largest Female-Male unpaid care work ratio. This correlates to length of tine females sacrifice and are unable to further their professional careers.

# %% [markdown]
# Now let's analyze actual employee survey data to gain an understanding of how real employees of both genders truly feel about their jobs and employment. This dataset is based upon a City of Tempe survey in 2018.
#
# Here is the dataset: https://data.world/city-of-tempe/053e6c31-6d76-46f4-b0b8-7ab10e466387https://data.world/city-of-tempe/053e6c31-6d76-46f4-b0b8-7ab10e466387

# %% [markdown]
# First let us just examine this dataset and observe some facts about it. This way we can gain a better understanding of what it may be able to provide

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'employee_survey_data.csv'
df = pd.read_csv(file_path)

# 1. Descriptive Statistics
print("Descriptive Statistics:")
print(df.describe(include='all'))
# Out:
# Descriptive Statistics:
#        Q1[1  I receive training to do my job ef  \
# count                                942.000000
# mean                                   3.821656
# std                                    1.177200
# min                                    1.000000
# 25%                                    3.000000
# 50%                                    4.000000
# 75%                                    5.000000
# max                                    9.000000
#
#        Q1[2  There is someone at work who encou  \
# count                                942.000000
# mean                                   3.642251
# std                                    1.405333
# min                                    1.000000
# 25%                                    3.000000
# 50%                                    4.000000
# 75%                                    5.000000
# max                                    9.000000
#
#        Q1[3  I have been mentored at work]  \
# count                           942.000000
# mean                              3.495754
# std                               1.586836
# min                               1.000000
# 25%                               2.000000
# 50%                               4.000000
# 75%                               4.000000
# max                               9.000000
#
#        Q1[4  I have received fair consideration  \
# count                                942.000000
# mean                                   3.921444
# std                                    2.012761
# min                                    1.000000
# 25%                                    3.000000
# 50%                                    4.000000
# 75%                                    5.000000
# max                                    9.000000
#
#        Q1[5  I am aware of the City's education  \
# count                                942.000000
# mean                                   4.154989
# std                                    1.299625
# min                                    1.000000
# 25%                                    4.000000
# 50%                                    4.000000
# 75%                                    5.000000
# max                                    9.000000
#
#        Q1[6  The City's programs related to pro  \
# count                                942.000000
# mean                                   3.785563
# std                                    1.940859
# min                                    1.000000
# 25%                                    3.000000
# 50%                                    3.000000
# 75%                                    4.000000
# max                                    9.000000
#
#        Q1[7  Overall  I am satisfied with the p  Q2[1  City Manager's Office]  \
# count                                942.000000                    942.000000
# mean                                   3.780255                      4.537155
# std                                    1.617358                      2.417655
# min                                    1.000000                      1.000000
# 25%                                    3.000000                      3.000000
# 50%                                    4.000000                      4.000000
# 75%                                    4.000000                      5.000000
# max                                    9.000000                      9.000000
#
#        Q2[2  Strategic Management and Diversity  Q2[3  Human Resources]  ...  \
# count                                942.000000              942.000000  ...
# mean                                   4.521231                4.067941  ...
# std                                    2.434056                1.873143  ...
# min                                    1.000000                1.000000  ...
# 25%                                    3.000000                3.000000  ...
# 50%                                    4.000000                4.000000  ...
# 75%                                    5.000000                5.000000  ...
# max                                    9.000000                9.000000  ...
#
#        Q8  Are you aware of the Council priorit  \
# count                                942.000000
# mean                                   1.843949
# std                                    1.924190
# min                                    1.000000
# 25%                                    1.000000
# 50%                                    1.000000
# 75%                                    2.000000
# max                                    9.000000
#
#        Q9  Are you proud to work for the City o  \
# count                                942.000000
# mean                                   2.094480
# std                                    2.697382
# min                                    1.000000
# 25%                                    1.000000
# 50%                                    1.000000
# 75%                                    1.000000
# max                                    9.000000
#
#        Q10  Overall  how satisfied are you with  \
# count                                942.000000
# mean                                   2.304671
# std                                    1.920182
# min                                    1.000000
# 25%                                    1.000000
# 50%                                    2.000000
# 75%                                    2.000000
# max                                    9.000000
#
#        Q11  How has the quality of the environm  \
# count                                942.000000
# mean                                   3.141189
# std                                    2.011186
# min                                    1.000000
# 25%                                    2.000000
# 50%                                    3.000000
# 75%                                    4.000000
# max                                    9.000000
#
#        Q12  Would you recommend the City of Tem  \
# count                                942.000000
# mean                                   2.435244
# std                                    2.982690
# min                                    1.000000
# 25%                                    1.000000
# 50%                                    1.000000
# 75%                                    1.000000
# max                                    9.000000
#
#        Q13  Does the City's working environment  \
# count                                942.000000
# mean                                   2.425690
# std                                    2.681122
# min                                    1.000000
# 25%                                    1.000000
# 50%                                    1.000000
# 75%                                    2.000000
# max                                    9.000000
#
#        Q14  I would like to finish my public se  \
# count                                942.000000
# mean                                   2.771762
# std                                    3.272909
# min                                    1.000000
# 25%                                    1.000000
# 50%                                    1.000000
# 75%                                    2.000000
# max                                    9.000000
#
#        Q15  I have applied for a new position w  \
# count                                942.000000
# mean                                   2.085987
# std                                    1.799762
# min                                    1.000000
# 25%                                    1.000000
# 50%                                    2.000000
# 75%                                    2.000000
# max                                    9.000000
#
#        Q16  What gender do you identify with?  \
# count                              942.000000
# mean                                 2.214437
# std                                  2.070152
# min                                  1.000000
# 25%                                  1.000000
# 50%                                  2.000000
# 75%                                  2.000000
# max                                  9.000000
#
#        Q18  In which department do you work?
# count                             942.000000
# mean                               17.313163
# std                                28.241042
# min                                 1.000000
# 25%                                 6.000000
# 50%                                 9.000000
# 75%                                 9.000000
# max                                99.000000
#
# [8 rows x 79 columns]

# %% [markdown]
# Now let us see which columns we can explore out of this database that may have some of the keywords that we are searching for.

# %%
import pandas as pd

# Load the dataset
file_path = 'employee_survey_data.csv'
df = pd.read_csv(file_path)

# Define keywords to search for in column names
keywords = ['safe', 'comfort', 'satisfied', 'support', 'fair']

# Find columns that contain any of the keywords
matching_columns = [col for col in df.columns if any(keyword in col.lower() for keyword in keywords)]

# Print the matching columns
print("Columns containing the keywords 'safe', 'comfort', 'satisfied', 'fair', or 'support':")
for column in matching_columns:
    print(column)
# Out:
# Columns containing the keywords 'safe', 'comfort', 'satisfied', 'fair', or 'support':
# Q1[4  I have received fair consideration
# Q1[7  Overall  I am satisfied with the p
# Q3[3  The Safe Haven process]
# Q3[7  The City supports those with a dis
# Q3[8  Overall  I am satisfied with the s
# Q4[4  I am comfortable expressing my opi
# Q4[12  My immediate supervisor supports
# Q4[17  As a supervisor  I am supported w
# Q4[23  I feel safe and comfortable in my
# Q4[26  Overall  I am satisfied with the
# Q5[5  The amount I am paid is fair for t
# Q5[6  I am satisfied with the City's def
# Q6[11  Overall  I am satisfied with the
# Q7[3  Overall  I am very satisfied with
# Q10  Overall  how satisfied are you with

# %% [markdown]
# Now let us plot how both men and women feel about safety in their workplace.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'employee_survey_data.csv'
df = pd.read_csv(file_path)

gender_columns = [col for col in df.columns if 'gender' in col.lower()]
comfort_columns = [col for col in df.columns if 'safe and comfortable' in col.lower()]

gender_column = gender_columns[0] if gender_columns else None
comfort_column = comfort_columns[0] if comfort_columns else None

filtered_df = df.dropna(subset=[gender_column, comfort_column])

unique_genders = filtered_df[gender_column].unique()[:2]

gender_mapping = {unique_genders[0]: 'Female', unique_genders[1]: 'Male'}
filtered_df['Gender Mapped'] = filtered_df[gender_column].map(gender_mapping)

# Plotting
plt.figure(figsize=(10, 6))
sns.boxplot(data=filtered_df, x='Gender Mapped', y=comfort_column, hue='Gender Mapped', palette='viridis')

# Add titles and labels
plt.title('Distribution of Comfort and Safety Felt at Work by Gender')
plt.xlabel('Gender')
plt.ylabel('Comfort and Safety Score')

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This allows us to gain a comprehensive understanding of what exactly is felt by each of the genders in the workplace. Additionally, we can understand the spread of female / male emotions rather than examining an average to truly capture all the data.

# %% [markdown]
# This concludes our exploratory analysis where we were able to examine a couple of datasets to visualize professional representation by gender, what women work with in terms of unpaid care work, and finally what each gender thinks about their job.
#
# To do this we went through some summary information about the data, and where outliers may exist especially in terms of opinions on feeling safe and comfortable in the workspace.
#
# However, this data isn't as focused on the question of the role that gender plays in opportunity. We have not fully explored what leadership opportunities look like for men vs women, pay discrepancies, educational roles, and career progress through age. We will also take a look at some of these through the lens of periods of time to ensure that we are measuring how the difference has changed over time.

# %% [markdown]
# ## Focused Analysis

# %% [markdown]
# * Code for data analysis directly relevant to questions of interest
# * Additional 4 data visualizations directly relevant to topic

# %% [markdown]
# ## Specific Data Research

# %% [markdown]
# We can start with preliminarily exploring what opportunity looks like for Women in leadership roles. To evaluate this, we will explore two datasets - one for US Senate Positions occupied, and one for CEOs.
# These datasets are sourced from:
# * https://www.pewresearch.org/social-trends/fact-sheet/the-data-on-women-leaders/

# %%
# Import necessary libraries
import pandas as pd

# Load the data
df = pd.read_csv('ceo_women.csv')

# Display the first few rows and column names to check the actual structure
print(df.head())
print(df.columns)
# Out:
#    Year Share of CEOs who are women
# 0  1995                        0.0%
# 1  1996                        0.2%
# 2  1997                        0.4%
# 3  1998                        0.4%
# 4  1999                        0.4%
# Index(['Year', 'Share of CEOs who are women'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('ceo_women.csv')

df['Share of CEOs who are women'] = df['Share of CEOs who are women'].str.rstrip('%').astype(float)

sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Share of CEOs who are women', marker='o', color='teal', linewidth=2)

plt.title('Women CEOs Overtime', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Women CEOs (%)', fontsize=12)

plt.grid(visible=True, which='both', linestyle='--', linewidth=0.5)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('senate_women.csv')

df['Women in Senate'] = df['Women in Senate'].str.rstrip('%').astype(float)

sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Women in Senate', marker='o', color='pink', linewidth=2)

plt.title('Women Senators Overtime', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Female Senators (%)', fontsize=12)

plt.grid(visible=True, which='both', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# Now lets see how much growth happens from year to year in terms of the percent increase in the women in leadership positions to understand where exactly they stand.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

senate_df = pd.read_csv('senate_women.csv')
ceo_df = pd.read_csv('ceo_women.csv')

senate_df['Women in Senate'] = senate_df['Women in Senate'].str.rstrip('%').astype(float)
ceo_df['Share of CEOs who are women'] = ceo_df['Share of CEOs who are women'].str.rstrip('%').astype(float)

senate_df['Senate Growth (%)'] = senate_df['Women in Senate'].diff().fillna(0)
ceo_df['CEO Growth (%)'] = ceo_df['Share of CEOs who are women'].diff().fillna(0)

combined_df = pd.merge(senate_df[['Year', 'Senate Growth (%)']], ceo_df[['Year', 'CEO Growth (%)']], on='Year')

sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.lineplot(data=combined_df, x='Year', y='Senate Growth (%)', marker='o', color='pink', linewidth=2, label='Women in Senate Growth')
sns.lineplot(data=combined_df, x='Year', y='CEO Growth (%)', marker='o', color='teal', linewidth=2, label='Women CEOs Growth')

plt.title('Yearly Percent Growth of Women in Leadership', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Percent Growth (%)', fontsize=12)

plt.grid(visible=True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Now lets examine the wage gap across the United States. This will allow us to have a better understanding of how women and men are paid for the same work. Here is the source that provided me with this data:
# * https://nwlc.org/resource/wage-gap-state-women-overall/#

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('gender_pay_gap.csv')
data['Full-Time Payment for Women/ Dollar Man Makes'] = data['Full-Time Payment for Women/ Dollar Man Makes'].replace('[\$,]', '', regex=True).astype(float)
data['Part-Time Payment for Women/ Dollar Man Makes'] = data['Part-Time Payment for Women/ Dollar Man Makes'].replace('[\$,]', '', regex=True).astype(float)

data_melted = data.melt(id_vars='State', 
                        value_vars=['Full-Time Payment for Women/ Dollar Man Makes', 'Part-Time Payment for Women/ Dollar Man Makes'],
                        var_name='Payment Type', 
                        value_name='Ratio')

sns.set(style='whitegrid')
plt.figure(figsize=(14, 8))
ax = sns.barplot(x='State', y='Ratio', hue='Payment Type', data=data_melted, palette='viridis')

ax.set_ylim(0, 1)
ax.set_xticks(ax.get_xticks())
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

plt.title('Comparison of Payment Ratios for Women vs. Men by State')
plt.xlabel('State')
plt.ylabel('Payment Ratio')

plt.legend(title='Payment Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's get a better contextual understanding of what this data means. In general, in the US how much money does a woman make for full-time and part-time roles as compared to a man.

# %%
import pandas as pd

data = pd.read_csv('gender_pay_gap.csv')
data['Full-Time Payment for Women/ Dollar Man Makes'] = data['Full-Time Payment for Women/ Dollar Man Makes'].replace('[\$,]', '', regex=True).astype(float)
data['Part-Time Payment for Women/ Dollar Man Makes'] = data['Part-Time Payment for Women/ Dollar Man Makes'].replace('[\$,]', '', regex=True).astype(float)

avg_full_time = data['Full-Time Payment for Women/ Dollar Man Makes'].mean()
avg_part_time = data['Part-Time Payment for Women/ Dollar Man Makes'].mean()

print(f"Average Full-Time Payment Ratio for Women (compared to a man's dollar): ${avg_full_time:.2f}")
print(f"Average Part-Time Payment Ratio for Women (compared to a man's dollar): ${avg_part_time:.2f}")
# Out:
# Average Full-Time Payment Ratio for Women (compared to a man's dollar): $0.82
# Average Part-Time Payment Ratio for Women (compared to a man's dollar): $0.74

# %% [markdown]
# It is time to examine average educational progress for both men and women. This will allow us to gain a key understanding of what has happened from an educational standpoint. Here is the source from which I gathered this data:
# * https://www.kaggle.com/datasets/noriuk/us-educational-attainment-19952015?select=1995_2015.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('educational_attainment.csv')

df_melted = df.melt(id_vars=['Year', 'Age_Range', 'Sex'], 
                    value_vars=['No_HS_Diploma', 'HS_Diploma', 'Some_College_No_Degree', 'Associate', 'Bachelor', 'Advanced'],
                    var_name='Education', 
                    value_name='Count')

df_filtered = df_melted[df_melted['Sex'] != 'Both']
df_agg = df_filtered.groupby(['Sex', 'Education'])['Count'].sum().reset_index()
df_pivot = df_agg.pivot_table(index='Sex', columns='Education', values='Count', fill_value=0)
ax = df_pivot.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='tab20')

plt.title('Educational Attainment by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Education Level')
plt.tight_layout()

plt.show()

# %% [markdown]
# Now lets examine the exact percentages of Male and Female in each Education Level so we can better compare exactly what the difference is.

# %%
import pandas as pd

# Read the data from a CSV file
df = pd.read_csv('educational_attainment.csv')
df_melted = df.melt(id_vars=['Year', 'Age_Range', 'Sex'], 
                    value_vars=['No_HS_Diploma', 'HS_Diploma', 'Some_College_No_Degree', 'Associate', 'Bachelor', 'Advanced'],
                    var_name='Education', 
                    value_name='Count')

df_filtered = df_melted[df_melted['Sex'] != 'Both']
df_agg = df_filtered.groupby(['Sex', 'Education'])['Count'].sum().reset_index()
df_pivot = df_agg.pivot_table(index='Sex', columns='Education', values='Count', fill_value=0)

total_counts = df_pivot.sum()
percentages = df_pivot.div(total_counts, axis=1) * 100

print("Percentages of Educational Attainment by Sex:")
print(percentages)
# Out:
# Percentages of Educational Attainment by Sex:
# Education   Advanced  Associate   Bachelor  HS_Diploma  No_HS_Diploma  \
# Sex
# Female     48.737167   55.19594  50.237357   46.018916      41.837629
# Male       51.262833   44.80406  49.762643   53.981084      58.162371
#
# Education  Some_College_No_Degree
# Sex
# Female                  50.663253
# Male                    49.336747

# %% [markdown]
# Now, we will examine a performance dataset of multiple students. This is to examine how Male and Female students score as compared to their gender, and will aid us in determining which on average do better. Here is the dataset:
# * https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('student_performance_data.csv')

df['Gender'] = df['Gender'].map({0: 'Male', 1: 'Female'})
gpa_by_gender = df.groupby('Gender')['GPA'].mean().reset_index()
absences_by_gender = df.groupby('Gender')['Absences'].mean().reset_index()

plt.figure(figsize=(14, 6))
sns.set_theme(style="whitegrid")

plt.subplot(1, 2, 1)
sns.barplot(
    x='Gender',
    y='GPA',
    data=gpa_by_gender,
    hue='Gender',
    palette='pastel',
    edgecolor=".6"
)
plt.title('Average GPA by Gender', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Average GPA', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.subplot(1, 2, 2)
sns.barplot(
    x='Gender',
    y='Absences',
    data=absences_by_gender,
    hue='Gender',
    palette='pastel',
    edgecolor=".6"
)
plt.title('Average Absences by Gender', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Average Absences', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# This visualization allows us to fully understand the distribution of GPA by gender, as well as the absences by gender. This way we can see how different genders potentially perform in school.
